# %%
import pandas as pd
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

# %%
# 5 zestawień i 5 wykresow
df = pd.read_csv('weekly-gasoline.csv')
df.drop('Fiscal Week', axis=1, inplace=True)
df['Fiscal Year'] = pd.to_datetime(df['Fiscal Year'], format='%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173 entries, 0 to 172
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Fiscal Year                          173 non-null    datetime64[ns]
#  1   Current Year Production              173 non-null    int64
#  2   Previous Year Production             173 non-null    int64
#  3   Difference From Same Week Last Year  172 non-null    object
#  4   Current Year Cumulative Production   173 non-null    int64
#  5   Cumulative Difference                173 non-null    object
# dtypes: datetime64[ns](1), int64(3), object(2)
# memory usage: 8.2+ KB

# %%
df_year =df.groupby('Fiscal Year').mean()

x=df_year.index
y=df_year["Current Year Production"]
z = df_year["Previous Year Production"]
# Out:
# /var/folders/ld/8f6qkgf90mz6vbcx6760y9rw0000gn/T/ipykernel_64962/2362056845.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_year =df.groupby('Fiscal Year').mean()

# %%
df_year.head(4)
# Out:
#              Current Year Production  Previous Year Production  \
# Fiscal Year
# 2020-01-01              2.470120e+09              2.734511e+09
# 2021-01-01              2.558772e+09              2.470120e+09
# 2022-01-01              2.607808e+09              2.510494e+09
# 2023-01-01              2.478108e+09              2.667150e+09
#
#              Current Year Cumulative Production
# Fiscal Year
# 2020-01-01                         6.691886e+10
# 2021-01-01                         6.565380e+10
# 2022-01-01                         7.091170e+10
# 2023-01-01                         2.137290e+10

# %%
fig, ax = plt.subplots(figsize=(10,4))
ax.plot(x, y, "r.--", label="Średnia produkcja benzyny")
ax.plot(x, z, "b.--", label="Średnia produkcja benzyny z poprzedniego roku")
plt.title("Średnia produkcja benzyny w USA")
ax.legend()

# %%
import numpy as np
y=df['Difference From Same Week Last Year']
y.replace(np.nan, 0, inplace=True)
y = y.astype("int")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 4
#       2 y=df['Difference From Same Week Last Year']
#       3 y.replace(np.nan, 0, inplace=True)
# ----> 4 y = y.astype("int")
#
# File ~/Desktop/Studia/Zaawansowane programowanie w języku Python/venv/lib/python3.10/site-packages/pandas/core/generic.py:6240, in NDFrame.astype(self, dtype, copy, errors)
#    6233     results = [
#    6234         self.iloc[:, i].astype(dtype, copy=copy)
#    6235         for i in range(len(self.columns))
#    6236     ]
#    6238 else:
#    6239     # else, only a single dtype is given
# -> 6240     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6241     return self._constructor(new_data).__finalize__(self, method="astype")
#    6243 # GH 33113: handle empty frame or series
#
# ...

# %%
plt.scatter(x, y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 plt.scatter(x, y)
#
# File ~/Desktop/Studia/Zaawansowane programowanie w języku Python/venv/lib/python3.10/site-packages/matplotlib/pyplot.py:2835, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2830 @_copy_docstring_and_deprecators(Axes.scatter)
#    2831 def scatter(
#    2832         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2833         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2834         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2835     __ret = gca().scatter(
#    2836         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2837         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# ...

# %%
y = df['Current Year Cumulative Production']
x = df['Fiscal Year']
x
# Out:
# 0     2023-01-01
# 1     2023-01-01
# 2     2023-01-01
# 3     2023-01-01
# 4     2023-01-01
#          ...
# 168   2020-01-01
# 169   2020-01-01
# 170   2020-01-01
# 171   2020-01-01
# 172   2020-01-01
# Name: Fiscal Year, Length: 173, dtype: datetime64[ns]

# %%
plt.plot(x, y)

# %%
y.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 173 entries, 0 to 172
# Series name: Current Year Cumulative Production
# Non-Null Count  Dtype
# --------------  -----
# 173 non-null    int64
# dtypes: int64(1)
# memory usage: 1.5 KB

# %%
y = df['Current Year Cumulative Production']
y
# Out:
# 0      39649722000
# 1      37255974000
# 2      34888098000
# 3      32666046000
# 4      30456930000
#           ...
# 168    13915902000
# 169    11227272000
# 170     8350776000
# 171     5531316000
# 172     2781240000
# Name: Current Year Cumulative Production, Length: 173, dtype: int64

# %%
x = df['Fiscal Year']

# %%
plt.plot(x, y)

# %%
y = df['Current Year Cumulative Production']

# %%
x = df['Fiscal Year']

# %%
plt.plot(x, y)

# %%
§
